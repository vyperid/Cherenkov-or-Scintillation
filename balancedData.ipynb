# %% [markdown]
# <a href="https://colab.research.google.com/github/vyperid/Cherenkov-or-Scintillation/blob/main/balancedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/data.csv")
# Out:
# <ipython-input-3-d793cd4a8ced>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/data.csv")

# %%
vector_1 = data[data['Vector'] == 1]
vector_1
# Out:
#         PMTN     Time  Vector   Energy
# 0       20.0  2.26446     1.0   2.8457
# 2       21.0  2.05006     1.0  3.12491
# 7        3.0  2.46323     1.0  3.18674
# 14      14.0  2.12233     1.0  2.81004
# 15      10.0  2.82026     1.0  3.38294
# ...      ...      ...     ...      ...
# 502820  15.0  3.00925     1.0   2.8438
# 502831   6.0  2.19857     1.0  2.65203
# 502832   0.0  2.15269     1.0  2.61014
# 502844   2.0  2.12418     1.0  2.56971
# 502845   2.0  2.22500     1.0  3.09619
#
# [93491 rows x 4 columns]

# %%
vector_0 = data[data['Vector'] == 0]
vector_0
# Out:
#         PMTN     Time  Vector     Energy
# 1       15.0  3.28770     0.0    3.14459
# 3        7.0  5.20787     0.0    3.12056
# 4        3.0  2.67362     0.0    3.18642
# 5       10.0  8.62977     0.0  3.06638\n
# 6       10.0  5.37959     0.0    3.15461
# ...      ...      ...     ...        ...
# 502855   8.0  2.91855     0.0    3.10635
# 502856   6.0  4.55664     0.0    3.54848
# 502857   3.0  3.81991     0.0    3.54944
# 502858  12.0  2.14133     0.0    3.42516
# 502859  13.0  2.39561     0.0    3.23639
#
# [409365 rows x 4 columns]

# %%
balanced_data = pd.concat([vector_0.sample(35000), vector_1.sample(38000)], axis=0)
balanced_data
# Out:
#         PMTN      Time  Vector   Energy
# 238910   0.0   3.01161     0.0  3.41565
# 242505  15.0   2.89710     0.0  2.94247
# 431778  17.0  10.72470     0.0  3.32107
# 72892    6.0   3.61331     0.0   3.3828
# 472569  18.0   2.39737     0.0  3.19104
# ...      ...       ...     ...      ...
# 204091  16.0   1.54555     1.0  2.82604
# 415435  20.0   2.91402     1.0  3.52526
# 290800  19.0   1.97154     1.0  3.41537
# 105938   0.0   4.25603     1.0  2.48986
# 495629   5.0   2.31558     1.0  3.36986
#
# [73000 rows x 4 columns]

# %%
balanced_data = balanced_data.sample(frac=1).reset_index(drop=True)
balanced_data
# Out:
#        PMTN     Time  Vector   Energy
# 0      21.0  2.14257     1.0  2.79987
# 1       9.0  2.77533     0.0  2.99431
# 2       2.0  2.26669     1.0  3.22359
# 3       1.0  2.15300     1.0  2.68785
# 4      20.0  2.04387     1.0  2.31785
# ...     ...      ...     ...      ...
# 72995   9.0  6.90020     0.0  3.55792
# 72996   9.0  4.63924     0.0  3.21144
# 72997   3.0  2.30114     1.0  3.52133
# 72998  18.0  2.37081     0.0  3.25085
# 72999  14.0  3.54083     0.0  3.41069
#
# [73000 rows x 4 columns]

# %%
balanced_data.to_csv("balanced_data.csv")
